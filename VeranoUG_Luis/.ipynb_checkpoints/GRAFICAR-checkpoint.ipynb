# %%
import numpy as np
import emcee
import matplotlib.pyplot as plt
import scipy.stats as st
import math
import random
import scipy.optimize as op
import corner
import emcee
import corner

# %%
potencial = np.loadtxt('pot.dat')
g = np.loadtxt('g.dat')
e = np.loadtxt('e.dat')

# %%
potencial
# Out:
# array([[2.18780968e-03, 1.00000000e+10],
#        [4.37561936e-03, 1.00000000e+10],
#        [6.56342904e-03, 1.00000000e+10],
#        ...,
#        [7.65295826e+00, 0.00000000e+00],
#        [7.65514607e+00, 0.00000000e+00],
#        [7.65733388e+00, 0.00000000e+00]])

# %%
plt.plot(potencial[457:,0], potencial[457:,1])

# %%
plt.plot(g[0:,0], g[0:,1])

# %%
plt.plot(e[0:,0], e[0:,1])
