# %%
import numpy as np
import emcee
import matplotlib.pyplot as plt
import scipy.stats as st
import math
import random
import scipy.optimize as op
import corner
import emcee
import corner

# %%
potencial = np.loadtxt('pot.dat')
potencial2 = np.loadtxt('pot2.dat')

# %%
g = np.loadtxt('g.dat')
e = np.loadtxt('e.dat')

# %% [markdown]
# 570 para bd
# 457 para mc

# %%
plt.plot(potencial[480:,0], potencial[480:,1])

# %%
plt.plot(potencial2[560:,0], potencial2[560:,1])

# %%
plt.plot(g[0:,0], g[0:,1])

# %%
plt.plot(e[0:,0], e[0:,1])
