# %%
import numpy as np
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
potencial = np.loadtxt('pot200.dat')
g = np.loadtxt('g2.dat')
e = np.loadtxt('e2.dat')
confin = np.loadtxt('conf_fin2.dat')
# Out:
# /home/luiscantero/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: loadtxt: Empty input file: "g2.dat"

# %% [markdown]
# ## Grafica del potencial

# %%
plt.plot(potencial[450:,0], potencial[450:,1])
plt.ylim(-1.9,0.3)
plt.xlim(0.75,1.4)
# Out:
# (0.75, 1.4)

# %% [markdown]
# ## Grafica de factor de distribucion radial g(r)

# %%
plt.plot(g[0:,0], g[0:,1])
plt.xlim(0,3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-2618973398e5> in <module>()
# ----> 1 plt.plot(g[0:,0], g[0:,1])
#       2 plt.xlim(0,3)
#
# IndexError: too many indices for array

# %% [markdown]
# ## Grafica de energia por particula

# %%
plt.rcParams["figure.figsize"] = (15,8)
plt.plot(e[0:,0], e[0:,1])

# %% [markdown]
# ## Configuracion final

# %%
fig = pyplot.figure()
ax = Axes3D(fig)          
ax.scatter(confin[0:,0], confin[0:,1], confin[0:,2])
#plt.ylim(-10, 55, 55)
