# %%
import numpy as np
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
potencial = np.loadtxt('pot.dat')
g = np.loadtxt('g.dat')
e = np.loadtxt('e.dat')
s = np.loadtxt('s.dat')
confin = np.loadtxt('conf_fin.dat')

# %% [markdown]
# ## Grafica del potencial

# %%
plt.plot(potencial[450:,0], potencial[450:,1])
plt.ylim(-1.9,0.3)
plt.xlim(0.75,1.4)
# Out:
# (0.75, 1.4)

# %% [markdown]
# ## Grafica de s(q)

# %%
fig, ax = plt.subplots()
ax.semilogx(s[0:,0], s[0:,1],color= 'y', label='h=0.10', linewidth = 3)
plt.legend()

# %% [markdown]
# ## Grafica de factor de distribucion radial g(r)

# %%
plt.plot(g[0:,0], g[0:,1])
plt.xlim(0,3)
# Out:
# (0, 3)

# %% [markdown]
# ## Grafica de energia por particula

# %%
plt.plot(e[0:,0], e[0:,1])

# %% [markdown]
# ## Configuracion final

# %%
fig = pyplot.figure()
ax = Axes3D(fig)          
ax.scatter(confin[0:,0], confin[0:,1], confin[0:,2])
#plt.ylim(-10, 55, 55)
